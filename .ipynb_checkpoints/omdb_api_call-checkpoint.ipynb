# %%
# Dependencies
import requests
import pandas as pd
url = "http://www.omdbapi.com/?apikey=trilogy&t="

# %%
df=pd.read_csv("dataset/top_5_movies.csv")
df.head()
# Out:
#    Unnamed: 0  Rank                         Title Studio   Total Gross  \
# 0           0     1                    Home Alone    Fox  $285,761,243
# 1           1     2                         Ghost   Par.  $217,631,306
# 2           2     3            Dances with Wolves  Orion  $184,208,848
# 3           3     4                  Pretty Woman     BV  $178,406,268
# 4           4     5  Teenage Mutant Ninja Turtles     NL  $135,265,915
#
#   Theaters      Opening Opening Theaters  Year  \
# 0    2,173  $17,081,997            1,202  1990
# 1    1,766  $12,191,540            1,101  1990
# 2    1,636     $598,257               14  1990
# 3    1,811  $11,280,591            1,325  1990
# 4    2,377  $25,398,367            2,006  1990
#
#                                         link  \
# 0                  /movies/?id=homealone.htm
# 1                      /movies/?id=ghost.htm
# 2           /movies/?id=danceswithwolves.htm
# 3                /movies/?id=prettywoman.htm
# 4  /movies/?id=teenagemutantninjaturtles.htm
#
#                                     Actors
# 0                          Macaulay Culkin
# 1  Patrick SwayzeDemi MooreWhoopi Goldberg
# 2                            Kevin Costner
# 3                Richard GereJulia Roberts
# 4                            Sam Rockwell*

# %%
responses=[]
for index, row in df.iterrows():
    movie = row["Title"]
    year = row["Year"]
    if(movie):
        if(year):
            movie_data = requests.get(url + movie + "&y=" + str(year)).json()
            responses.append(movie_data)
responses
# Out:
# [{'Actors': 'Macaulay Culkin, Joe Pesci, Daniel Stern, John Heard',
#   'Awards': 'Nominated for 2 Oscars. Another 10 wins & 4 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '05 Oct 1999',
#   'Director': 'Chris Columbus',
#   'Genre': 'Comedy, Family',
#   'Language': 'English',
#   'Metascore': '63',
#   'Plot': 'An eight-year-old troublemaker must protect his house from a pair of burglars when he is accidentally left home alone by his family during Christmas vacation.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzFkM2YwOTQtYzk2Mi00N2VlLWE3NTItN2YwNDg1YmY0ZDNmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#   'Production': 'Twentieth Century Fox',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '62%'},
#    {'Source': 'Metacritic', 'Value': '63/100'}],
#   'Released': '16 Nov 1990',
#   'Response': 'True',
#   'Runtime': '103 min',
#   'Title': 'Home Alone',
#   'Type': 'movie',
#   'Website': 'http://www.foxhome.com/homealone/index_frames.html',
#   'Writer': 'John Hughes',
#   'Year': '1990',
#   'imdbID': 'tt0099785',
#   'imdbRating': '7.5',
#   'imdbVotes': '373,263'},
#  {'Actors': 'Patrick Swayze, Demi Moore, Whoopi Goldberg, Tony Goldwyn',
#   'Awards': 'Won 2 Oscars. Another 16 wins & 23 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '24 Apr 2001',
#   'Director': 'Jerry Zucker',
#   'Genre': 'Drama, Fantasy, Romance',
#   'Language': 'English',
#   'Metascore': '52',
#   'Plot': 'After a young man is murdered, his spirit stays behind to warn his lover of impending danger, with the help of a reluctant psychic.',
#   'Poster': 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NzQzODUzNl5BMl5BanBnXkFtZTgwMjc5NTYxMTE@._V1_SX300.jpg',
#   'Production': 'Paramount Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#    {'Source': 'Metacritic', 'Value': '52/100'}],
#   'Released': '13 Jul 1990',
#   'Response': 'True',
#   'Runtime': '127 min',
#   'Title': 'Ghost',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Bruce Joel Rubin',
#   'Year': '1990',
#   'imdbID': 'tt0099653',
#   'imdbRating': '7.0',
#   'imdbVotes': '167,948'},
#  {'Actors': 'Kevin Costner, Mary McDonnell, Graham Greene, Rodney A. Grant',
#   'Awards': 'Won 7 Oscars. Another 43 wins & 37 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA, UK',
#   'DVD': '17 Jun 2003',
#   'Director': 'Kevin Costner',
#   'Genre': 'Adventure, Drama, Western',
#   'Language': 'English, Sioux, Pawnee',
#   'Metascore': '72',
#   'Plot': 'Lieutenant John Dunbar, assigned to a remote western Civil War outpost, befriends wolves and Indians, making him an intolerable aberration in the military.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTY3OTI5NDczN15BMl5BanBnXkFtZTcwNDA0NDY3Mw@@._V1_SX300.jpg',
#   'Production': 'Orion Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '82%'},
#    {'Source': 'Metacritic', 'Value': '72/100'}],
#   'Released': '21 Nov 1990',
#   'Response': 'True',
#   'Runtime': '181 min',
#   'Title': 'Dances with Wolves',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Michael Blake (screenplay), Michael Blake (novel)',
#   'Year': '1990',
#   'imdbID': 'tt0099348',
#   'imdbRating': '8.0',
#   'imdbVotes': '206,943'},
#  {'Actors': 'Richard Gere, Julia Roberts, Ralph Bellamy, Jason Alexander',
#   'Awards': 'Nominated for 1 Oscar. Another 8 wins & 10 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '19 May 1998',
#   'Director': 'Garry Marshall',
#   'Genre': 'Comedy, Romance',
#   'Language': 'English',
#   'Metascore': '51',
#   'Plot': 'A man in a legal but hurtful business needs an escort for some social events, and hires a beautiful prostitute he meets... only to fall in love.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNjk2ODQzNDYxNV5BMl5BanBnXkFtZTgwMTcyNDg4NjE@._V1_SX300.jpg',
#   'Production': 'Buena Vista',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '61%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Released': '23 Mar 1990',
#   'Response': 'True',
#   'Runtime': '119 min',
#   'Title': 'Pretty Woman',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'J.F. Lawton',
#   'Year': '1990',
#   'imdbID': 'tt0100405',
#   'imdbRating': '7.0',
#   'imdbVotes': '242,365'},
#  {'Actors': 'Judith Hoag, Elias Koteas, Josh Pais, David Forman',
#   'Awards': '3 wins & 3 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA, Hong Kong',
#   'DVD': '16 Dec 1997',
#   'Director': 'Steve Barron',
#   'Genre': 'Action, Adventure, Comedy',
#   'Language': 'English, French',
#   'Metascore': 'N/A',
#   'Plot': 'Four teenage mutant ninja turtles emerge from the shadows to protect New York City from a gang of criminal ninjas.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNzg3NTQ4NDk5NV5BMl5BanBnXkFtZTgwNzMzNDg4NjE@._V1_SX300.jpg',
#   'Production': 'New Line Cinema',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '40%'}],
#   'Released': '30 Mar 1990',
#   'Response': 'True',
#   'Runtime': '93 min',
#   'Title': 'Teenage Mutant Ninja Turtles',
#   'Type': 'movie',
#   'Website': 'http://www.ninjaturtles.com/',
#   'Writer': 'Kevin Eastman (characters), Peter Laird (characters), Bobby Herbeck (story), Todd W. Langen (screenplay), Bobby Herbeck (screenplay)',
#   'Year': '1990',
#   'imdbID': 'tt0100758',
#   'imdbRating': '6.7',
#   'imdbVotes': '75,072'},
#  {'Actors': 'Walter Noon, Arnold Schwarzenegger, James Cameron, Linda Hamilton',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': 'N/A',
#   'Director': 'David G. Hudson, Ed W. Marsh',
#   'Genre': 'Documentary, Short',
#   'Language': 'English, Spanish',
#   'Metascore': 'N/A',
#   'Plot': 'Documentary of the making of Terminator 2 (1991) the sequel to the popular Schwarzenegger film, The Terminator (1984).',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNTQyYzJjZmItZWIwMi00ZDFlLTliNjAtZDdjYTc4M2MxNTU3XkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'NOT RATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}],
#   'Released': '09 Sep 1991',
#   'Response': 'True',
#   'Runtime': '25 min',
#   'Title': "The Making of 'Terminator 2: Judgment Day'",
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '1991',
#   'imdbID': 'tt0271049',
#   'imdbRating': '7.1',
#   'imdbVotes': '303'},
#  {'Actors': 'Kevin Costner, Morgan Freeman, Mary Elizabeth Mastrantonio, Christian Slater',
#   'Awards': 'Nominated for 1 Oscar. Another 16 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '30 Sep 1997',
#   'Director': 'Kevin Reynolds',
#   'Genre': 'Action, Adventure, Drama',
#   'Language': 'English, Arabic',
#   'Metascore': '51',
#   'Plot': 'When Robin and his Moorish companion come to England and the tyranny of the Sheriff of Nottingham, he decides to fight back as an outlaw.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BODM3MjA3NDM3M15BMl5BanBnXkFtZTgwMDc1NjUwMjI@._V1_SX300.jpg',
#   'Production': 'Warner Bros. Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '49%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Released': '14 Jun 1991',
#   'Response': 'True',
#   'Runtime': '143 min',
#   'Title': 'Robin Hood: Prince of Thieves',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Pen Densham (story), Pen Densham (screenplay), John Watson (screenplay)',
#   'Year': '1991',
#   'imdbID': 'tt0102798',
#   'imdbRating': '6.9',
#   'imdbVotes': '158,360'},
#  {'Actors': 'Robby Benson, Jesse Corti, Rex Everhart, Angela Lansbury',
#   'Awards': 'Won 2 Oscars. Another 24 wins & 25 nominations.',
#   'BoxOffice': '$47,611,331',
#   'Country': 'USA',
#   'DVD': '08 Oct 2002',
#   'Director': 'Gary Trousdale, Kirk Wise',
#   'Genre': 'Animation, Family, Fantasy',
#   'Language': 'English, French',
#   'Metascore': '95',
#   'Plot': 'A young woman whose father has been imprisoned by a terrifying beast offers herself in his place, unaware that her captor is actually a prince, physically altered by a magic spell.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzE5MDM1NDktY2I0OC00YWI5LTk2NzUtYjczNDczOWQxYjM0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': 'Buena Vista',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#    {'Source': 'Metacritic', 'Value': '95/100'}],
#   'Released': '22 Nov 1991',
#   'Response': 'True',
#   'Runtime': '84 min',
#   'Title': 'Beauty and the Beast',
#   'Type': 'movie',
#   'Website': 'http://www.disney.com/beautyandthebeast',
#   'Writer': 'Linda Woolverton (animation screenplay by), Brenda Chapman (story by), Chris Sanders (story by), Burny Mattinson (story by), Kevin Harkey (story by), Brian Pimental (story by), Bruce Woodside (story by), Joe Ranft (story by), Tom Ellery (story by), Kelly Asbury (story by), Robert Lence (story by)',
#   'Year': '1991',
#   'imdbID': 'tt0101414',
#   'imdbRating': '8.0',
#   'imdbVotes': '367,756'},
#  {'Actors': 'Jodie Foster, Lawrence A. Bonney, Kasi Lemmons, Lawrence T. Wrentz',
#   'Awards': 'Won 5 Oscars. Another 54 wins & 44 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '01 Jul 1998',
#   'Director': 'Jonathan Demme',
#   'Genre': 'Crime, Drama, Thriller',
#   'Language': 'English',
#   'Metascore': '85',
#   'Plot': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNjNhZTk0ZmEtNjJhMi00YzFlLWE1MmEtYzM1M2ZmMGMwMTU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'Orion Pictures Corporation',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#    {'Source': 'Metacritic', 'Value': '85/100'}],
#   'Released': '14 Feb 1991',
#   'Response': 'True',
#   'Runtime': '118 min',
#   'Title': 'The Silence of the Lambs',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Thomas Harris (novel), Ted Tally (screenplay)',
#   'Year': '1991',
#   'imdbID': 'tt0102926',
#   'imdbRating': '8.6',
#   'imdbVotes': '1,047,075'},
#  {'Actors': 'Billy Crystal, Daniel Stern, Bruno Kirby, Patricia Wettig',
#   'Awards': 'Won 1 Oscar. Another 7 wins & 7 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '04 Feb 1999',
#   'Director': 'Ron Underwood',
#   'Genre': 'Comedy',
#   'Language': 'English',
#   'Metascore': '70',
#   'Plot': 'On the verge of turning 40, an unhappy Manhattan yuppie is roped into joining his two friends on a cattle drive in the southwest.',
#   'Poster': 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkwNjM2MTc5NF5BMl5BanBnXkFtZTcwMzQ2NjEzNA@@._V1_SX300.jpg',
#   'Production': 'Columbia Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#    {'Source': 'Metacritic', 'Value': '70/100'}],
#   'Released': '07 Jun 1991',
#   'Response': 'True',
#   'Runtime': '113 min',
#   'Title': 'City Slickers',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Lowell Ganz, Babaloo Mandel',
#   'Year': '1991',
#   'imdbID': 'tt0101587',
#   'imdbRating': '6.7',
#   'imdbVotes': '42,100'},
#  {'Actors': 'Scott Weinger, Robin Williams, Linda Larkin, Jonathan Freeman',
#   'Awards': 'Won 2 Oscars. Another 30 wins & 22 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '05 Oct 2004',
#   'Director': 'Ron Clements, John Musker',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Language': 'English',
#   'Metascore': 'N/A',
#   'Plot': "When a street urchin vies for the love of a beautiful princess, he uses a genie's magic power to make himself off as a prince in order to marry her.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BY2Q2NDI1MjUtM2Q5ZS00MTFlLWJiYWEtNTZmNjQ3OGJkZDgxXkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_SX300.jpg',
#   'Production': 'Buena Vista Distribution Compa',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '94%'}],
#   'Released': '25 Nov 1992',
#   'Response': 'True',
#   'Runtime': '90 min',
#   'Title': 'Aladdin',
#   'Type': 'movie',
#   'Website': 'http://disney.go.com/vault/archives/characters/aladdin/aladdin.html',
#   'Writer': 'Ron Clements (screenplay by), John Musker (screenplay by), Ted Elliott (screenplay by), Terry Rossio (screenplay by), Burny Mattinson (story), Roger Allers (story), Daan Jippes (story), Kevin Harkey (story), Sue C. Nichols (story), Francis Glebas (story), Darrell Rooney (story), Larry Leker (story), James Fujii (story), Kirk Hanson (story), Kevin Lima (story), Rebecca Rees (story), David S. Smith (story), Chris Sanders (story), Brian Pimental (story), Patrick A. Ventura (story)',
#   'Year': '1992',
#   'imdbID': 'tt0103639',
#   'imdbRating': '8.0',
#   'imdbVotes': '299,270'},
#  {'Actors': "Macaulay Culkin, Joe Pesci, Daniel Stern, Catherine O'Hara",
#   'Awards': '3 wins & 3 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '05 Oct 1999',
#   'Director': 'Chris Columbus',
#   'Genre': 'Adventure, Comedy, Family',
#   'Language': 'English, French',
#   'Metascore': 'N/A',
#   'Plot': 'One year after Kevin was left home alone and had to defeat a pair of bumbling burglars, he accidentally finds himself in New York City, and the same criminals are not far behind.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNDI1MzM0Y2YtYmIyMS00ODE3LTlhZjEtZTUyNmEzMTNhZWU5XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': '20th Century Fox',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '30%'}],
#   'Released': '20 Nov 1992',
#   'Response': 'True',
#   'Runtime': '120 min',
#   'Title': 'Home Alone 2: Lost in New York',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'John Hughes (characters), John Hughes',
#   'Year': '1992',
#   'imdbID': 'tt0104431',
#   'imdbRating': '6.6',
#   'imdbVotes': '241,311'},
#  {'Actors': 'Michael Keaton, Danny DeVito, Michelle Pfeiffer, Christopher Walken',
#   'Awards': 'Nominated for 2 Oscars. Another 2 wins & 27 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA, UK',
#   'DVD': '29 Apr 1997',
#   'Director': 'Tim Burton',
#   'Genre': 'Action, Crime, Fantasy',
#   'Language': 'English',
#   'Metascore': '68',
#   'Plot': 'When a corrupt businessman and the grotesque Penguin plot to take control of Gotham City, only Batman can stop them, while the Catwoman has her own agenda.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BOGZmYzVkMmItM2NiOS00MDI3LWI4ZWQtMTg0YWZkODRkMmViXkEyXkFqcGdeQXVyODY0NzcxNw@@._V1_SX300.jpg',
#   'Production': 'Warner Bros. Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Released': '19 Jun 1992',
#   'Response': 'True',
#   'Runtime': '126 min',
#   'Title': 'Batman Returns',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Bob Kane (Batman characters), Daniel Waters (story), Sam Hamm (story), Daniel Waters (screenplay)',
#   'Year': '1992',
#   'imdbID': 'tt0103776',
#   'imdbRating': '7.0',
#   'imdbVotes': '239,893'},
#  {'Actors': 'Mel Gibson, Danny Glover, Joe Pesci, Rene Russo',
#   'Awards': '3 wins & 4 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '16 Dec 1997',
#   'Director': 'Richard Donner',
#   'Genre': 'Action, Crime, Thriller',
#   'Language': 'English',
#   'Metascore': '36',
#   'Plot': 'Martin Riggs and Roger Murtaugh pursue a former LAPD officer who uses his knowledge of police procedure and policies to steal and sell confiscated guns and ammunition to local street gangs.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BOTFlNjI0NDQtMzlkNC00ZDU0LWE0ODktYmI2OTc2YjZlZmVlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': 'Warner Home Video',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#    {'Source': 'Metacritic', 'Value': '36/100'}],
#   'Released': '15 May 1992',
#   'Response': 'True',
#   'Runtime': '118 min',
#   'Title': 'Lethal Weapon 3',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Jeffrey Boam (screenplay), Jeffrey Boam (screenplay by), Robert Mark Kamen (screenplay by), Jeffrey Boam (story by), Shane Black (characters)',
#   'Year': '1992',
#   'imdbID': 'tt0104714',
#   'imdbRating': '6.7',
#   'imdbVotes': '139,887'},
#  {'Actors': 'Tom Cruise, Jack Nicholson, Demi Moore, Kevin Bacon',
#   'Awards': 'Nominated for 4 Oscars. Another 10 wins & 26 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '07 Oct 1997',
#   'Director': 'Rob Reiner',
#   'Genre': 'Drama, Thriller',
#   'Language': 'English, French',
#   'Metascore': '62',
#   'Plot': 'Military lawyer Lieutenant Daniel Kaffee defends Marines accused of murder. They contend they were acting under orders.',
#   'Poster': 'https://images-na.ssl-images-amazon.com/images/M/MV5BMmRlZDQ1MmUtMzE2Yi00YTkxLTk1MGMtYmIyYWQwODcxYzRlXkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_SX300.jpg',
#   'Production': 'Columbia Pictures',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#    {'Source': 'Metacritic', 'Value': '62/100'}],
#   'Released': '11 Dec 1992',
#   'Response': 'True',
#   'Runtime': '138 min',
#   'Title': 'A Few Good Men',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Aaron Sorkin (play), Aaron Sorkin (screenplay)',
#   'Year': '1992',
#   'imdbID': 'tt0104257',
#   'imdbRating': '7.7',
#   'imdbVotes': '200,293'},
#  {'Actors': 'Sam Neill, Laura Dern, Jeff Goldblum, Richard Attenborough',
#   'Awards': 'Won 3 Oscars. Another 32 wins & 25 nominations.',
#   'BoxOffice': '$45,299,680',
#   'Country': 'USA',
#   'DVD': '10 Oct 2000',
#   'Director': 'Steven Spielberg',
#   'Genre': 'Adventure, Sci-Fi, Thriller',
#   'Language': 'English, Spanish',
#   'Metascore': '68',
#   'Plot': 'During a preview tour, a theme park suffers a major power breakdown that allows its cloned dinosaur exhibits to run amok.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjM2MDgxMDg0Nl5BMl5BanBnXkFtZTgwNTM2OTM5NDE@._V1_SX300.jpg',
#   'Production': 'Universal City Studios',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Released': '11 Jun 1993',
#   'Response': 'True',
#   'Runtime': '127 min',
#   'Title': 'Jurassic Park',
#   'Type': 'movie',
#   'Website': 'http://www.jurassicpark.com/maingate_flash.html',
#   'Writer': 'Michael Crichton (novel), Michael Crichton (screenplay), David Koepp (screenplay)',
#   'Year': '1993',
#   'imdbID': 'tt0107290',
#   'imdbRating': '8.1',
#   'imdbVotes': '724,340'},
#  {'Actors': 'Robin Williams, Sally Field, Pierce Brosnan, Harvey Fierstein',
#   'Awards': 'Won 1 Oscar. Another 10 wins & 9 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '05 Oct 1999',
#   'Director': 'Chris Columbus',
#   'Genre': 'Comedy, Drama, Family',
#   'Language': 'English',
#   'Metascore': '53',
#   'Plot': 'After a bitter divorce, an actor disguises himself as a female housekeeper to spend time with his children held in custody by his former wife.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjExMDUzODE1N15BMl5BanBnXkFtZTgwNTU5NTYxMTE@._V1_SX300.jpg',
#   'Production': '20th Century Fox',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '53/100'}],
#   'Released': '24 Nov 1993',
#   'Response': 'True',
#   'Runtime': '125 min',
#   'Title': 'Mrs. Doubtfire',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Anne Fine (novel), Randi Mayem Singer (screenplay), Leslie Dixon (screenplay)',
#   'Year': '1993',
#   'imdbID': 'tt0107614',
#   'imdbRating': '6.9',
#   'imdbVotes': '206,695'},
#  {'Actors': 'Harrison Ford, Tommy Lee Jones, Sela Ward, Julianne Moore',
#   'Awards': 'Won 1 Oscar. Another 11 wins & 33 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '24 Nov 1998',
#   'Director': 'Andrew Davis',
#   'Genre': 'Action, Crime, Drama',
#   'Language': 'English, Polish, Spanish',
#   'Metascore': '88',
#   'Plot': 'Dr. Richard Kimble, unjustly accused of murdering his wife, must find the real killer while being the target of a nationwide manhunt lead by a seasoned US Marshall.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYmFmOGZjYTItYjY1ZS00OWRiLTk0NDgtMjQ5MzBkYWE2YWE0XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'Warner Bros. Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#    {'Source': 'Metacritic', 'Value': '88/100'}],
#   'Released': '06 Aug 1993',
#   'Response': 'True',
#   'Runtime': '130 min',
#   'Title': 'The Fugitive',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Jeb Stuart (screenplay), David Twohy (screenplay), David Twohy (story), Roy Huggins (characters)',
#   'Year': '1993',
#   'imdbID': 'tt0106977',
#   'imdbRating': '7.8',
#   'imdbVotes': '234,267'},
#  {'Actors': 'Tom Cruise, Jeanne Tripplehorn, Gene Hackman, Hal Holbrook',
#   'Awards': 'Nominated for 2 Oscars. Another 3 wins & 5 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '23 May 2000',
#   'Director': 'Sydney Pollack',
#   'Genre': 'Drama, Mystery, Thriller',
#   'Language': 'English',
#   'Metascore': '58',
#   'Plot': 'A young lawyer joins a prestigious law firm only to discover that it has a sinister dark side.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTgxMjM5NDYwM15BMl5BanBnXkFtZTgwODkzMzk5MDE@._V1_SX300.jpg',
#   'Production': 'Paramount Pictures',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#    {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Released': '30 Jun 1993',
#   'Response': 'True',
#   'Runtime': '154 min',
#   'Title': 'The Firm',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'John Grisham (novel), David Rabe (screenplay), Robert Towne (screenplay), David Rayfiel (screenplay)',
#   'Year': '1993',
#   'imdbID': 'tt0106918',
#   'imdbRating': '6.8',
#   'imdbVotes': '98,904'},
#  {'Actors': 'Tom Hanks, Ross Malinger, Rita Wilson, Victor Garber',
#   'Awards': 'Nominated for 2 Oscars. Another 4 wins & 17 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '26 Jun 1997',
#   'Director': 'Nora Ephron',
#   'Genre': 'Comedy, Drama, Romance',
#   'Language': 'English',
#   'Metascore': '72',
#   'Plot': "A recently widowed man's son calls a radio talk-show in an attempt to find his father a partner.",
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNWY1MDJkZGUtZTE2OS00ODZiLTlmNzQtMDZjNzM2ZjkwM2QxXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#   'Production': 'TriStar Pictures',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '72/100'}],
#   'Released': '25 Jun 1993',
#   'Response': 'True',
#   'Runtime': '105 min',
#   'Title': 'Sleepless in Seattle',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Jeff Arch (story), Nora Ephron (screenplay), David S. Ward (screenplay), Jeff Arch (screenplay)',
#   'Year': '1993',
#   'imdbID': 'tt0108160',
#   'imdbRating': '6.8',
#   'imdbVotes': '137,361'},
#  {'Actors': 'Tom Hanks, Rebecca Williams, Sally Field, Michael Conner Humphreys',
#   'Awards': 'Won 6 Oscars. Another 40 wins & 67 nominations.',
#   'BoxOffice': '$330,000,000',
#   'Country': 'USA',
#   'DVD': '28 Aug 2001',
#   'Director': 'Robert Zemeckis',
#   'Genre': 'Drama, Romance',
#   'Language': 'English',
#   'Metascore': '82',
#   'Plot': 'The presidencies of Kennedy and Johnson, Vietnam, Watergate, and other history unfold through the perspective of an Alabama man with an IQ of 75.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': 'Paramount Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#    {'Source': 'Metacritic', 'Value': '82/100'}],
#   'Released': '06 Jul 1994',
#   'Response': 'True',
#   'Runtime': '142 min',
#   'Title': 'Forrest Gump',
#   'Type': 'movie',
#   'Website': 'http://www.paramount.com/movies/forrest-gump/',
#   'Writer': 'Winston Groom (novel), Eric Roth (screenplay)',
#   'Year': '1994',
#   'imdbID': 'tt0109830',
#   'imdbRating': '8.8',
#   'imdbVotes': '1,486,006'},
#  {'Actors': 'Rowan Atkinson, Matthew Broderick, Niketa Calame-Harris, Jim Cummings',
#   'Awards': 'Won 2 Oscars. Another 33 wins & 29 nominations.',
#   'BoxOffice': '$94,240,635',
#   'Country': 'USA',
#   'DVD': '07 Oct 2003',
#   'Director': 'Roger Allers, Rob Minkoff',
#   'Genre': 'Animation, Adventure, Drama',
#   'Language': 'English, Swahili, Xhosa, Zulu',
#   'Metascore': '83',
#   'Plot': "A Lion cub crown prince is tricked by a treacherous uncle into thinking he caused his father's death and flees into exile in despair, only to learn in adulthood his identity and his responsibilities.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BYTYxNGMyZTYtMjE3MS00MzNjLWFjNmYtMDk3N2FmM2JiM2M1XkEyXkFqcGdeQXVyNjY5NDU4NzI@._V1_SX300.jpg',
#   'Production': 'Buena Vista',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#    {'Source': 'Metacritic', 'Value': '83/100'}],
#   'Released': '24 Jun 1994',
#   'Response': 'True',
#   'Runtime': '88 min',
#   'Title': 'The Lion King',
#   'Type': 'movie',
#   'Website': 'http://disney.go.com/lionking/',
#   'Writer': 'Irene Mecchi (screenplay by), Jonathan Roberts (screenplay by), Linda Woolverton (screenplay by), Burny Mattinson (story), Barry Johnson (story), Lorna Cook (story), Thom Enriquez (story), Andy Gaskill (story), Gary Trousdale (story), Jim Capobianco (story), Kevin Harkey (story), Jorgen Klubien (story), Chris Sanders (story), Tom Sito (story), Larry Leker (story), Joe Ranft (story), Rick Maki (story), Ed Gombert (story), Francis Glebas (story), Mark Kausler (story), J.T. Allen (additional story material), George Scribner (additional story material), Miguel Tejada-Flores (additional story material), Jenny Tripp (additional story material), Bob Tzudiker (additional story material), Christopher Vogler (additional story material), Kirk Wise (additional story material), Noni White (additional story material), Brenda Chapman (story supervisor)',
#   'Year': '1994',
#   'imdbID': 'tt0110357',
#   'imdbRating': '8.5',
#   'imdbVotes': '765,804'},
#  {'Actors': 'Arnold Schwarzenegger, Jamie Lee Curtis, Tom Arnold, Bill Paxton',
#   'Awards': 'Nominated for 1 Oscar. Another 7 wins & 20 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '25 May 1999',
#   'Director': 'James Cameron',
#   'Genre': 'Action, Comedy, Thriller',
#   'Language': 'English, French, Arabic, German',
#   'Metascore': '63',
#   'Plot': 'A fearless, globe-trotting, terrorist-battling secret agent has his life turned upside down when he discovers his wife might be having an affair with a used car salesman while terrorists smuggle nuclear war heads into the United States.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BYzg5YmUyNGMtMThiNS00MjA2LTgwZDctNDlhM2RkZDNmZmRkXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#   'Production': '20th Century Fox',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#    {'Source': 'Metacritic', 'Value': '63/100'}],
#   'Released': '15 Jul 1994',
#   'Response': 'True',
#   'Runtime': '141 min',
#   'Title': 'True Lies',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Claude Zidi (screenplay "La Totale!"), Simon Michaël (screenplay "La Totale!"), Didier Kaminka (screenplay "La Totale!"), James Cameron (screenplay)',
#   'Year': '1994',
#   'imdbID': 'tt0111503',
#   'imdbRating': '7.2',
#   'imdbVotes': '209,278'},
#  {'Actors': 'Tim Allen, Judge Reinhold, Wendy Crewson, Eric Lloyd',
#   'Awards': '2 wins & 8 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '13 Oct 1998',
#   'Director': 'John Pasquin',
#   'Genre': 'Comedy, Drama, Family',
#   'Language': 'English, Spanish',
#   'Metascore': '57',
#   'Plot': 'When a man inadvertantly kills Santa on Christmas Eve, he finds himself magically recruited to take his place.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTZlNzk1MjItYjJlYy00MTAxLWJkNjEtZmNiNmVlNjQ4NDE5XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SX300.jpg',
#   'Production': 'Buena Vista Distribution Compa',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#    {'Source': 'Metacritic', 'Value': '57/100'}],
#   'Released': '11 Nov 1994',
#   'Response': 'True',
#   'Runtime': '97 min',
#   'Title': 'The Santa Clause',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Leo Benvenuti, Steve Rudnick',
#   'Year': '1994',
#   'imdbID': 'tt0111070',
#   'imdbRating': '6.4',
#   'imdbVotes': '77,140'},
#  {'Actors': "John Goodman, Elizabeth Perkins, Rick Moranis, Rosie O'Donnell",
#   'Awards': '6 wins & 10 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '16 Mar 1999',
#   'Director': 'Brian Levant',
#   'Genre': 'Comedy, Family, Fantasy',
#   'Language': 'English',
#   'Metascore': '38',
#   'Plot': "In this live-action feature of the cartoon show, Fred Flintstone finally gets the job he's always wanted, but it may just come at a price.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BYzY0ZTk4YzctNzYzNy00ZDQ0LTg2Y2ItZTQyYzQxMjQwMDc2XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#   'Production': 'MCA Universal Home Video',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#    {'Source': 'Metacritic', 'Value': '38/100'}],
#   'Released': '27 May 1994',
#   'Response': 'True',
#   'Runtime': '91 min',
#   'Title': 'The Flintstones',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Tom S. Parker, Jim Jennewein, Steven E. de Souza',
#   'Year': '1994',
#   'imdbID': 'tt0109813',
#   'imdbRating': '4.8',
#   'imdbVotes': '66,754'},
#  {'Actors': 'Tom Hanks, Tim Allen, Don Rickles, Jim Varney',
#   'Awards': 'Nominated for 3 Oscars. Another 23 wins & 17 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '20 Mar 2001',
#   'Director': 'John Lasseter',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Language': 'English',
#   'Metascore': '95',
#   'Plot': "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_SX300.jpg',
#   'Production': 'Buena Vista',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'},
#    {'Source': 'Metacritic', 'Value': '95/100'}],
#   'Released': '22 Nov 1995',
#   'Response': 'True',
#   'Runtime': '81 min',
#   'Title': 'Toy Story',
#   'Type': 'movie',
#   'Website': 'http://www.disney.com/ToyStory',
#   'Writer': 'John Lasseter (original story by), Pete Docter (original story by), Andrew Stanton (original story by), Joe Ranft (original story by), Joss Whedon (screenplay by), Andrew Stanton (screenplay by), Joel Cohen (screenplay by), Alec Sokolow (screenplay by)',
#   'Year': '1995',
#   'imdbID': 'tt0114709',
#   'imdbRating': '8.3',
#   'imdbVotes': '733,458'},
#  {'Actors': 'Val Kilmer, Tommy Lee Jones, Jim Carrey, Nicole Kidman',
#   'Awards': 'Nominated for 3 Oscars. Another 10 wins & 22 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA, UK',
#   'DVD': '27 Aug 1997',
#   'Director': 'Joel Schumacher',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Language': 'English',
#   'Metascore': '51',
#   'Plot': 'Batman must battle former district attorney Harvey Dent, who is now Two-Face and Edward Nygma, The Riddler with help from an amorous psychologist and a young circus acrobat who becomes his sidekick, Robin.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNWY3M2I0YzItNzA1ZS00MzE3LThlYTEtMTg2YjNiOTYzODQ1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': 'Warner Bros. Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '39%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Released': '16 Jun 1995',
#   'Response': 'True',
#   'Runtime': '121 min',
#   'Title': 'Batman Forever',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Bob Kane (characters), Lee Batchler (story), Janet Scott Batchler (story), Lee Batchler (screenplay), Janet Scott Batchler (screenplay), Akiva Goldsman (screenplay)',
#   'Year': '1995',
#   'imdbID': 'tt0112462',
#   'imdbRating': '5.4',
#   'imdbVotes': '210,821'},
#  {'Actors': 'Tom Hanks, Bill Paxton, Kevin Bacon, Gary Sinise',
#   'Awards': 'Won 2 Oscars. Another 24 wins & 49 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '07 Sep 2004',
#   'Director': 'Ron Howard',
#   'Genre': 'Adventure, Drama, History',
#   'Language': 'English',
#   'Metascore': '77',
#   'Plot': 'NASA must devise a strategy to return Apollo 13 to Earth safely after the spacecraft undergoes massive internal damage putting the lives of the three astronauts on board in jeopardy.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNjEzYjJmNzgtNDkwNy00MTQ4LTlmMWMtNzA4YjE2NjI0ZDg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'Universal Pictures',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#    {'Source': 'Metacritic', 'Value': '77/100'}],
#   'Released': '30 Jun 1995',
#   'Response': 'True',
#   'Runtime': '140 min',
#   'Title': 'Apollo 13',
#   'Type': 'movie',
#   'Website': 'http://www.imax.com/apollo13',
#   'Writer': 'Jim Lovell (book), Jeffrey Kluger (book), William Broyles Jr. (screenplay), Al Reinert (screenplay)',
#   'Year': '1995',
#   'imdbID': 'tt0112384',
#   'imdbRating': '7.6',
#   'imdbVotes': '232,490'},
#  {'Actors': 'Joe Baker, Christian Bale, Irene Bedard, Billy Connolly',
#   'Awards': 'Won 2 Oscars. Another 13 wins & 6 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '06 Jun 2000',
#   'Director': 'Mike Gabriel, Eric Goldberg',
#   'Genre': 'Animation, Adventure, Drama',
#   'Language': 'English, Algonquin',
#   'Metascore': '58',
#   'Plot': 'An English soldier and the daughter of an Algonquin chief share a romance when English colonists invade seventeenth-century Virginia.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMzc4YzhiN2ItY2Y4NC00YTA0LWEyMjEtNzllNTcxZDdjODhiXkEyXkFqcGdeQXVyNTUyMzE4Mzg@._V1_SX300.jpg',
#   'Production': 'Buena Vista Distribution Compa',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#    {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Released': '23 Jun 1995',
#   'Response': 'True',
#   'Runtime': '81 min',
#   'Title': 'Pocahontas',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Carl Binder, Susannah Grant, Philip LaZebnik, Glen Keane (story), Joe Grant (story), Ralph Zondag (story), Burny Mattinson (story), Ed Gombert (story), Kaan Kalyon (story), Francis Glebas (story), Rob Gibbs (story), Bruce Morris (story), Todd Kurosawa (story), Duncan Marjoribanks (story), Chris Buck (story), Mike Gabriel (based on an idea by), Andrew Chapman (additional story development), Randy Cartwright (additional story development), Will Finn (additional story development), Broose Johnson (additional story development), T. Daniel Hofstedt (additional story development), David Pruiksma (additional story development), Nik Ranieri (additional story development), Vincent DeFrances (additional story development), Tom Mazzocco (additional story development), Don Dougherty (additional story development), Jorgen Klubien (additional story development)',
#   'Year': '1995',
#   'imdbID': 'tt0114148',
#   'imdbRating': '6.7',
#   'imdbVotes': '140,529'},
#  {'Actors': 'Jim Carrey, Ian McNeice, Simon Callow, Maynard Eziashi',
#   'Awards': '7 wins & 6 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '30 Oct 1997',
#   'Director': 'Steve Oedekerk',
#   'Genre': 'Adventure, Comedy, Crime',
#   'Language': 'English',
#   'Metascore': '45',
#   'Plot': 'Ace Ventura, Pet Detective, returns from a spiritual quest to investigate the disappearance of a rare white bat, the sacred animal of a tribe in Africa.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNGFiYTgxZDctNGI4OS00MWU1LWIwOGUtZmMyNGQxYjVkZjQ3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': 'Warner Home Video',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#    {'Source': 'Metacritic', 'Value': '45/100'}],
#   'Released': '10 Nov 1995',
#   'Response': 'True',
#   'Runtime': '90 min',
#   'Title': 'Ace Ventura: When Nature Calls',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Jack Bernstein (characters), Steve Oedekerk',
#   'Year': '1995',
#   'imdbID': 'tt0112281',
#   'imdbRating': '6.3',
#   'imdbVotes': '178,321'},
#  {'Actors': 'Will Smith, Bill Pullman, Jeff Goldblum, Mary McDonnell',
#   'Awards': 'Won 1 Oscar. Another 34 wins & 34 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '27 Jun 2000',
#   'Director': 'Roland Emmerich',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Language': 'English',
#   'Metascore': '59',
#   'Plot': "The aliens are coming and their goal is to invade and destroy Earth. Fighting superior technology, mankind's best weapon is the will to survive.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMGQwNDNkMmItYWY1Yy00YTZmLWE5OTAtODU0MGZmMzQ1NDdkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': '20th Century Fox',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '62%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Released': '03 Jul 1996',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Independence Day',
#   'Type': 'movie',
#   'Website': 'http://www.foxhome.com/id4dvd/html/index_flash.html',
#   'Writer': 'Dean Devlin, Roland Emmerich',
#   'Year': '1996',
#   'imdbID': 'tt0116629',
#   'imdbRating': '7.0',
#   'imdbVotes': '473,416'},
#  {'Actors': 'Helen Hunt, Bill Paxton, Cary Elwes, Jami Gertz',
#   'Awards': 'Nominated for 2 Oscars. Another 10 wins & 15 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '06 Jun 2000',
#   'Director': 'Jan de Bont',
#   'Genre': 'Action, Adventure, Drama',
#   'Language': 'English',
#   'Metascore': '68',
#   'Plot': 'Bill and Jo Harding, advanced storm chasers on the brink of divorce, must join together to create an advanced weather alert system by putting themselves in the cross-hairs of extremely violent tornadoes.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BODExYTM0MzEtZGY2Yy00N2ExLTkwZjItNGYzYTRmMWZlOGEzXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#   'Production': 'Warner Bros. Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Released': '10 May 1996',
#   'Response': 'True',
#   'Runtime': '113 min',
#   'Title': 'Twister',
#   'Type': 'movie',
#   'Website': 'http://movies.warnerbros.com/twister/',
#   'Writer': 'Michael Crichton, Anne-Marie Martin',
#   'Year': '1996',
#   'imdbID': 'tt0117998',
#   'imdbRating': '6.3',
#   'imdbVotes': '155,209'},
#  {'Actors': 'Tom Cruise, Jon Voight, Emmanuelle Béart, Henry Czerny',
#   'Awards': '3 wins & 14 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '17 Jan 1998',
#   'Director': 'Brian De Palma',
#   'Genre': 'Action, Adventure, Thriller',
#   'Language': 'English, French, Czech',
#   'Metascore': '59',
#   'Plot': 'An American agent, under false suspicion of disloyalty, must discover and expose the real spy without the help of his organization.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc3NjI2MjU0Nl5BMl5BanBnXkFtZTgwNDk3ODYxMTE@._V1_SX300.jpg',
#   'Production': 'Paramount Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '62%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Released': '22 May 1996',
#   'Response': 'True',
#   'Runtime': '110 min',
#   'Title': 'Mission: Impossible',
#   'Type': 'movie',
#   'Website': 'http://www.missionimpossible.com/',
#   'Writer': 'Bruce Geller (television series), David Koepp (story), Steven Zaillian (story), David Koepp (screenplay), Robert Towne (screenplay)',
#   'Year': '1996',
#   'imdbID': 'tt0117060',
#   'imdbRating': '7.1',
#   'imdbVotes': '333,761'},
#  {'Actors': 'Tom Cruise, Cuba Gooding Jr., Renée Zellweger, Kelly Preston',
#   'Awards': 'Won 1 Oscar. Another 25 wins & 41 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '24 Jun 1997',
#   'Director': 'Cameron Crowe',
#   'Genre': 'Comedy, Drama, Romance',
#   'Language': 'English, American Sign Language',
#   'Metascore': '77',
#   'Plot': 'When a sports agent has a moral epiphany and is fired for expressing it, he decides to put his new philosophy to the test as an independent agent with the only athlete who stays with him and his former secretary.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BYTM0ZWNmZTUtOTVkZS00MTZiLTg3M2QtZjA0Y2RmOWM1NWEyXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'TriStar Pictures',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#    {'Source': 'Metacritic', 'Value': '77/100'}],
#   'Released': '13 Dec 1996',
#   'Response': 'True',
#   'Runtime': '139 min',
#   'Title': 'Jerry Maguire',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Cameron Crowe',
#   'Year': '1996',
#   'imdbID': 'tt0116695',
#   'imdbRating': '7.3',
#   'imdbVotes': '210,478'},
#  {'Actors': 'Mel Gibson, Rene Russo, Brawley Nolte, Gary Sinise',
#   'Awards': 'Nominated for 1 Golden Globe. Another 3 wins & 4 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '15 Jan 2002',
#   'Director': 'Ron Howard',
#   'Genre': 'Action, Crime, Thriller',
#   'Language': 'English',
#   'Metascore': '60',
#   'Plot': "When a multimillionaire man's son is kidnapped, he cooperates with the police at first but then turns the tables on the kidnappers when he uses the ransom money as a reward for the capture of the kidnappers.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BZTc0ZjNkYTktMmJmOS00OTJlLTg1NWUtMzQ5ZGMxM2NhY2M0L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#   'Production': 'Touchstone Pictures',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#    {'Source': 'Metacritic', 'Value': '60/100'}],
#   'Released': '08 Nov 1996',
#   'Response': 'True',
#   'Runtime': '121 min',
#   'Title': 'Ransom',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Cyril Hume (story), Richard Maibaum (story), Richard Price (screenplay), Alexander Ignon (screenplay)',
#   'Year': '1996',
#   'imdbID': 'tt0117438',
#   'imdbRating': '6.6',
#   'imdbVotes': '106,552'},
#  {'Actors': 'Leonardo DiCaprio, Kate Winslet, Billy Zane, Kathy Bates',
#   'Awards': 'Won 11 Oscars. Another 111 wins & 77 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '10 Sep 2012',
#   'Director': 'James Cameron',
#   'Genre': 'Drama, Romance',
#   'Language': 'English, Swedish',
#   'Metascore': '75',
#   'Plot': 'A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMDdmZGU3NDQtY2E5My00ZTliLWIzOTUtMTY4ZGI1YjdiNjk3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg',
#   'Production': 'Paramount Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#    {'Source': 'Metacritic', 'Value': '75/100'}],
#   'Released': '19 Dec 1997',
#   'Response': 'True',
#   'Runtime': '194 min',
#   'Title': 'Titanic',
#   'Type': 'movie',
#   'Website': 'http://www.titanicmovie.com/',
#   'Writer': 'James Cameron',
#   'Year': '1997',
#   'imdbID': 'tt0120338',
#   'imdbRating': '7.8',
#   'imdbVotes': '893,280'},
#  {'Actors': "Tommy Lee Jones, Will Smith, Linda Fiorentino, Vincent D'Onofrio",
#   'Awards': 'Won 1 Oscar. Another 19 wins & 39 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '23 Oct 1997',
#   'Director': 'Barry Sonnenfeld',
#   'Genre': 'Adventure, Comedy, Family',
#   'Language': 'English, Spanish',
#   'Metascore': '71',
#   'Plot': 'A police officer joins a secret organization that polices and monitors extraterrestrial interactions on Earth.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BOTlhYTVkMDktYzIyNC00NzlkLTlmN2ItOGEyMWQ4OTA2NDdmXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#   'Production': 'Columbia TriStar International',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '71/100'}],
#   'Released': '02 Jul 1997',
#   'Response': 'True',
#   'Runtime': '98 min',
#   'Title': 'Men in Black',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Lowell Cunningham (comic), Ed Solomon (screen story), Ed Solomon (screenplay)',
#   'Year': '1997',
#   'imdbID': 'tt0119654',
#   'imdbRating': '7.3',
#   'imdbVotes': '450,278'},
#  {'Actors': 'Jeff Goldblum, Julianne Moore, Pete Postlethwaite, Arliss Howard',
#   'Awards': 'Nominated for 1 Oscar. Another 4 wins & 23 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '10 Oct 2000',
#   'Director': 'Steven Spielberg',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Language': 'English, Spanish',
#   'Metascore': '59',
#   'Plot': 'A research team is sent to the Jurassic Park Site B island to study the dinosaurs there while another team approaches with another agenda.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMDFlMmM4Y2QtNDg1ZS00MWVlLTlmODgtZDdhYjY5YjdhN2M0XkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_SX300.jpg',
#   'Production': 'Universal Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '53%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Released': '23 May 1997',
#   'Response': 'True',
#   'Runtime': '129 min',
#   'Title': 'The Lost World: Jurassic Park',
#   'Type': 'movie',
#   'Website': 'http://www.lost-world.com/',
#   'Writer': 'Michael Crichton (novel), David Koepp (screenplay)',
#   'Year': '1997',
#   'imdbID': 'tt0119567',
#   'imdbRating': '6.5',
#   'imdbVotes': '316,719'},
#  {'Actors': 'Jim Carrey, Maura Tierney, Justin Cooper, Cary Elwes',
#   'Awards': 'Nominated for 1 Golden Globe. Another 4 wins & 5 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '20 Jan 1998',
#   'Director': 'Tom Shadyac',
#   'Genre': 'Comedy, Fantasy',
#   'Language': 'English',
#   'Metascore': '70',
#   'Plot': "A fast-track lawyer can't lie for 24 hours due to his son's birthday wish after he turns his son down for the last time.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BYjZlYmJjYWYtZDM0NS00YmZlLWIyMTAtMDY5ZTNjZTgwMDhjXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': 'Universal Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '81%'},
# ...
#   'Production': 'Universal Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Released': '12 Jun 2015',
#   'Response': 'True',
#   'Runtime': '124 min',
#   'Title': 'Jurassic World',
#   'Type': 'movie',
#   'Website': 'http://www.jurassicworldmovie.com/',
#   'Writer': 'Rick Jaffa (screenplay by), Amanda Silver (screenplay by), Colin Trevorrow (screenplay by), Derek Connolly (screenplay by), Rick Jaffa (story by), Amanda Silver (story by), Michael Crichton (based on the characters created by)',
#   'Year': '2015',
#   'imdbID': 'tt0369610',
#   'imdbRating': '7.0',
#   'imdbVotes': '490,840'},
#  {'Actors': 'Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans',
#   'Awards': '7 wins & 45 nominations.',
#   'BoxOffice': '$429,113,729',
#   'Country': 'USA',
#   'DVD': '02 Oct 2015',
#   'Director': 'Joss Whedon',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Language': 'English, Korean',
#   'Metascore': '66',
#   'Plot': "When Tony Stark and Bruce Banner try to jump-start a dormant peacekeeping program called Ultron, things go horribly wrong and it's up to Earth's mightiest heroes to stop the villainous Ultron from enacting his terrible plan.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTM4OGJmNWMtOTM4Ni00NTE3LTg3MDItZmQxYjc4N2JhNmUxXkEyXkFqcGdeQXVyNTgzMDMzMTg@._V1_SX300.jpg',
#   'Production': 'Walt Disney Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Released': '01 May 2015',
#   'Response': 'True',
#   'Runtime': '141 min',
#   'Title': 'Avengers: Age of Ultron',
#   'Type': 'movie',
#   'Website': 'http://marvel.com/avengers',
#   'Writer': 'Joss Whedon, Stan Lee (based on the Marvel comics by), Jack Kirby (based on the Marvel comics by), Joe Simon (character created by: Captain America), Jack Kirby (character created by: Captain America), Jim Starlin (character created by: Thanos)',
#   'Year': '2015',
#   'imdbID': 'tt2395427',
#   'imdbRating': '7.4',
#   'imdbVotes': '585,569'},
#  {'Actors': 'Amy Poehler, Phyllis Smith, Richard Kind, Bill Hader',
#   'Awards': 'Won 1 Oscar. Another 93 wins & 112 nominations.',
#   'BoxOffice': '$264,317,903',
#   'Country': 'USA',
#   'DVD': '03 Nov 2015',
#   'Director': 'Pete Docter, Ronnie Del Carmen(co-director)',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Language': 'English',
#   'Metascore': '94',
#   'Plot': 'After young Riley is uprooted from her Midwest life and moved to San Francisco, her emotions - Joy, Fear, Anger, Disgust and Sadness - conflict on how best to navigate a new city, house, and school.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BOTgxMDQwMDk0OF5BMl5BanBnXkFtZTgwNjU5OTg2NDE@._V1_SX300.jpg',
#   'Production': 'Disney/Pixar',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '98%'},
#    {'Source': 'Metacritic', 'Value': '94/100'}],
#   'Released': '19 Jun 2015',
#   'Response': 'True',
#   'Runtime': '95 min',
#   'Title': 'Inside Out',
#   'Type': 'movie',
#   'Website': 'https://www.facebook.com/PixarInsideOut',
#   'Writer': 'Pete Docter (original story by), Ronnie Del Carmen (original story by), Pete Docter (screenplay by), Meg LeFauve (screenplay by), Josh Cooley (screenplay by), Michael Arndt (additional story material by), Simon Rich (additional story material by), Bill Hader (additional dialogue by), Amy Poehler (additional dialogue by)',
#   'Year': '2015',
#   'imdbID': 'tt2096673',
#   'imdbRating': '8.2',
#   'imdbVotes': '481,449'},
#  {'Actors': 'Vin Diesel, Paul Walker, Jason Statham, Michelle Rodriguez',
#   'Awards': 'Nominated for 1 Golden Globe. Another 28 wins & 31 nominations.',
#   'BoxOffice': '$316,986,481',
#   'Country': 'Japan, USA',
#   'DVD': '15 Sep 2015',
#   'Director': 'James Wan',
#   'Genre': 'Action, Crime, Thriller',
#   'Language': 'English',
#   'Metascore': '67',
#   'Plot': 'Deckard Shaw seeks revenge against Dominic Toretto and his family for his comatose brother.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTQxOTA2NDUzOV5BMl5BanBnXkFtZTgwNzY2MTMxMzE@._V1_SX300.jpg',
#   'Production': 'Universal Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '80%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Released': '03 Apr 2015',
#   'Response': 'True',
#   'Runtime': '137 min',
#   'Title': 'Furious 7',
#   'Type': 'movie',
#   'Website': 'http://www.furious7.com/',
#   'Writer': 'Chris Morgan, Gary Scott Thompson (characters)',
#   'Year': '2015',
#   'imdbID': 'tt2820852',
#   'imdbRating': '7.2',
#   'imdbVotes': '320,169'},
#  {'Actors': 'Felicity Jones, Diego Luna, Alan Tudyk, Donnie Yen',
#   'Awards': 'Nominated for 2 Oscars. Another 23 wins & 78 nominations.',
#   'BoxOffice': '$532,171,696',
#   'Country': 'USA',
#   'DVD': '04 Apr 2017',
#   'Director': 'Gareth Edwards',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Language': 'English',
#   'Metascore': '65',
#   'Plot': 'The daughter of an Imperial scientist joins the Rebel Alliance in a risky move to steal the Death Star plans.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjEwMzMxODIzOV5BMl5BanBnXkFtZTgwNzg3OTAzMDI@._V1_SX300.jpg',
#   'Production': 'Walt Disney Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#    {'Source': 'Metacritic', 'Value': '65/100'}],
#   'Released': '16 Dec 2016',
#   'Response': 'True',
#   'Runtime': '133 min',
#   'Title': 'Rogue One: A Star Wars Story',
#   'Type': 'movie',
#   'Website': 'http://www.starwars.com/',
#   'Writer': 'Chris Weitz (screenplay by), Tony Gilroy (screenplay by), John Knoll (story by), Gary Whitta (story by), George Lucas (based on characters created by)',
#   'Year': '2016',
#   'imdbID': 'tt3748528',
#   'imdbRating': '7.8',
#   'imdbVotes': '423,372'},
#  {'Actors': "Ellen DeGeneres, Albert Brooks, Ed O'Neill, Kaitlin Olson",
#   'Awards': 'Nominated for 1 BAFTA Film Award. Another 15 wins & 42 nominations.',
#   'BoxOffice': '$486,292,984',
#   'Country': 'USA',
#   'DVD': '15 Nov 2016',
#   'Director': 'Andrew Stanton, Angus MacLane(co-director)',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Language': 'English, Indonesian',
#   'Metascore': '77',
#   'Plot': 'The friendly but forgetful blue tang fish, Dory, begins a search for her long-lost parents, and everyone learns a few things about the real meaning of family along the way.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BNzg4MjM2NDQ4MV5BMl5BanBnXkFtZTgwMzk3MTgyODE@._V1_SX300.jpg',
#   'Production': 'Walt Disney Pictures/PIXAR',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#    {'Source': 'Metacritic', 'Value': '77/100'}],
#   'Released': '17 Jun 2016',
#   'Response': 'True',
#   'Runtime': '97 min',
#   'Title': 'Finding Dory',
#   'Type': 'movie',
#   'Website': 'http://movies.disney.com/finding-dory',
#   'Writer': 'Andrew Stanton (original story by), Andrew Stanton (screenplay by), Victoria Strouse (screenplay by), Bob Peterson (additional screenplay material by), Angus MacLane (additional story material by)',
#   'Year': '2016',
#   'imdbID': 'tt2277860',
#   'imdbRating': '7.3',
#   'imdbVotes': '190,783'},
#  {'Actors': 'Chris Evans, Robert Downey Jr., Scarlett Johansson, Sebastian Stan',
#   'Awards': '16 wins & 65 nominations.',
#   'BoxOffice': '$408,080,554',
#   'Country': 'USA, Germany',
#   'DVD': '13 Sep 2016',
#   'Director': 'Anthony Russo, Joe Russo',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Language': 'English, German, Xhosa, Russian, Romanian, Hindi',
#   'Metascore': '75',
#   'Plot': "Political involvement in the Avengers' activities causes a rift between Captain America and Iron Man.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjQ0MTgyNjAxMV5BMl5BanBnXkFtZTgwNjUzMDkyODE@._V1_SX300.jpg',
#   'Production': 'Walt Disney Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#    {'Source': 'Metacritic', 'Value': '75/100'}],
#   'Released': '06 May 2016',
#   'Response': 'True',
#   'Runtime': '147 min',
#   'Title': 'Captain America: Civil War',
#   'Type': 'movie',
#   'Website': 'http://marvel.com/captainamerica#/home',
#   'Writer': 'Christopher Markus (screenplay by), Stephen McFeely (screenplay by), Joe Simon (based on the Marvel comics by), Jack Kirby (based on the Marvel comics by)',
#   'Year': '2016',
#   'imdbID': 'tt3498820',
#   'imdbRating': '7.8',
#   'imdbVotes': '495,979'},
#  {'Actors': 'Louis C.K., Eric Stonestreet, Kevin Hart, Jenny Slate',
#   'Awards': '4 wins & 15 nominations.',
#   'BoxOffice': '$368,305,960',
#   'Country': 'Japan, USA',
#   'DVD': '06 Dec 2016',
#   'Director': 'Chris Renaud, Yarrow Cheney(co-director)',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Language': 'English',
#   'Metascore': '61',
#   'Plot': 'The quiet life of a terrier named Max is upended when his owner takes in Duke, a stray whom Max instantly dislikes.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjIzMzA1OTkzNV5BMl5BanBnXkFtZTgwODE3MjM4NzE@._V1_SX300.jpg',
#   'Production': 'Universal Pictures',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#    {'Source': 'Metacritic', 'Value': '61/100'}],
#   'Released': '08 Jul 2016',
#   'Response': 'True',
#   'Runtime': '87 min',
#   'Title': 'The Secret Life of Pets',
#   'Type': 'movie',
#   'Website': 'http://www.thesecretlifeofpets.com/',
#   'Writer': 'Cinco Paul, Ken Daurio, Brian Lynch',
#   'Year': '2016',
#   'imdbID': 'tt2709768',
#   'imdbRating': '6.5',
#   'imdbVotes': '144,506'},
#  {'Error': 'Movie not found!', 'Response': 'False'},
#  {'Actors': 'Mark Hamill, Carrie Fisher, Adam Driver, Daisy Ridley',
#   'Awards': 'Nominated for 4 Oscars. Another 12 wins & 71 nominations.',
#   'BoxOffice': '$619,117,636',
#   'Country': 'USA',
#   'DVD': '27 Mar 2018',
#   'Director': 'Rian Johnson',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Language': 'English',
#   'Metascore': '85',
#   'Plot': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares for battle with the First Order.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_SX300.jpg',
#   'Production': 'Walt Disney Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#    {'Source': 'Metacritic', 'Value': '85/100'}],
#   'Released': '15 Dec 2017',
#   'Response': 'True',
#   'Runtime': '152 min',
#   'Title': 'Star Wars: The Last Jedi',
#   'Type': 'movie',
#   'Website': 'http://www.starwars.com/the-last-jedi/',
#   'Writer': 'Rian Johnson, George Lucas (based on characters created by)',
#   'Year': '2017',
#   'imdbID': 'tt2527336',
#   'imdbRating': '7.3',
#   'imdbVotes': '371,631'},
#  {'Error': 'Movie not found!', 'Response': 'False'},
#  {'Actors': 'Gal Gadot, Chris Pine, Connie Nielsen, Robin Wright',
#   'Awards': '17 wins & 54 nominations.',
#   'BoxOffice': '$412,400,625',
#   'Country': 'Hong Kong, China, USA',
#   'DVD': '19 Sep 2017',
#   'Director': 'Patty Jenkins',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Language': 'English, German, Dutch, French, Spanish, Chinese, Greek,  Ancient (to 1453), North American Indian',
#   'Metascore': '76',
#   'Plot': 'When a pilot crashes and tells of conflict in the outside world, Diana, an Amazonian warrior in training, leaves home to fight a war, discovering her full powers and true destiny.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDFmZjgyMTEtYTk5MC00NmY0LWJhZjktOWY2MzI5YjkzODNlXkEyXkFqcGdeQXVyMDA4NzMyOA@@._V1_SX300.jpg',
#   'Production': 'Warner Bros. Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '76/100'}],
#   'Released': '02 Jun 2017',
#   'Response': 'True',
#   'Runtime': '141 min',
#   'Title': 'Wonder Woman',
#   'Type': 'movie',
#   'Website': 'http://wonderwomanfilm.com/',
#   'Writer': 'Allan Heinberg (screenplay by), Zack Snyder (story by), Allan Heinberg (story by), Jason Fuchs (story by), William Moulton Marston (Wonder Woman created by)',
#   'Year': '2017',
#   'imdbID': 'tt0451279',
#   'imdbRating': '7.5',
#   'imdbVotes': '415,290'},
#  {'Actors': 'Dwayne Johnson, Kevin Hart, Jack Black, Karen Gillan',
#   'Awards': '2 wins & 3 nominations.',
#   'BoxOffice': '$393,201,353',
#   'Country': 'USA',
#   'DVD': '20 Mar 2018',
#   'Director': 'Jake Kasdan',
#   'Genre': 'Action, Adventure, Comedy',
#   'Language': 'English',
#   'Metascore': '58',
#   'Plot': 'Four teenagers are sucked into a magical video game, and the only way they can escape is to work together to finish the game.',
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BODQ0NDhjYWItYTMxZi00NTk2LWIzNDEtOWZiYWYxZjc2MTgxXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Production': 'Columbia Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#    {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Released': '20 Dec 2017',
#   'Response': 'True',
#   'Runtime': '119 min',
#   'Title': 'Jumanji: Welcome to the Jungle',
#   'Type': 'movie',
#   'Website': 'http://www.jumanjimovie.com/',
#   'Writer': 'Chris McKenna (screenplay by), Erik Sommers (screenplay by), Scott Rosenberg (screenplay by), Jeff Pinkner (screenplay by), Chris McKenna (screen story by), Chris Van Allsburg (based on the book "Jumanji" by), Greg Taylor (based on the film "Jumanji" screenplay by), Jim Strain (based on the film "Jumanji" screen story by), Chris Van Allsburg (based on the film "Jumanji" screen story by), Jonathan Hensleigh (based on the film "Jumanji" screenplay by), Greg Taylor (based on the film "Jumanji" screen story by), Jim Strain (based on the film "Jumanji" screenplay by)',
#   'Year': '2017',
#   'imdbID': 'tt2283362',
#   'imdbRating': '7.0',
#   'imdbVotes': '159,564'},
#  {'Actors': 'Chris Pratt, Zoe Saldana, Dave Bautista, Vin Diesel',
#   'Awards': 'Nominated for 1 Oscar. Another 12 wins & 42 nominations.',
#   'BoxOffice': '$389,804,217',
#   'Country': 'USA',
#   'DVD': '22 Aug 2017',
#   'Director': 'James Gunn',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Language': 'English',
#   'Metascore': '67',
#   'Plot': "The Guardians must fight to keep their newfound family together as they unravel the mystery of Peter Quill's true parentage.",
#   'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTg2MzI1MTg3OF5BMl5BanBnXkFtZTgwNTU3NDA2MTI@._V1_SX300.jpg',
#   'Production': 'Walt Disney Pictures',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Released': '05 May 2017',
#   'Response': 'True',
#   'Runtime': '136 min',
#   'Title': 'Guardians of the Galaxy Vol. 2',
#   'Type': 'movie',
#   'Website': 'https://marvel.com/guardians',
#   'Writer': 'James Gunn, Dan Abnett (based on the Marvel comics by), Andy Lanning (based on the Marvel comics by), Steve Englehart (Star-lord created by), Steve Gan (Star-lord created by), Jim Starlin (Gamora and Drax created by), Stan Lee (Groot created by), Larry Lieber (Groot created by), Jack Kirby (Groot created by), Bill Mantlo (Rocket Raccoon created by), Keith Giffen (Rocket Raccoon created by), Steve Gerber (Howard the Duck created by), Val Mayerik (Howard the Duck created by)',
#   'Year': '2017',
#   'imdbID': 'tt3896198',
#   'imdbRating': '7.7',
#   'imdbVotes': '378,906'}]

# %%
len(responses)
# Out:
# 140

# %%
# Out:
# ['Home Alone',
#  'Ghost',
#  'Dances with Wolves',
#  'Pretty Woman',
#  'Teenage Mutant Ninja Turtles',
#  'Terminator 2: Judgment Day',
#  'Robin Hood: Prince of Thieves',
#  'Beauty and the Beast',
#  'The Silence of the Lambs',
#  'City Slickers',
#  'Aladdin',
#  'Home Alone 2: Lost in New York',
#  'Batman Returns',
#  'Lethal Weapon 3',
#  'A Few Good Men',
#  'Jurassic Park',
#  'Mrs. Doubtfire',
#  'The Fugitive',
#  'The Firm',
#  'Sleepless in Seattle',
#  'Forrest Gump',
#  'The Lion King',
#  'True Lies',
#  'The Santa Clause',
#  'The Flintstones',
#  'Toy Story',
#  'Batman Forever',
#  'Apollo 13',
#  'Pocahontas',
#  'Ace Ventura: When Nature Calls',
#  'Independence Day',
#  'Twister',
#  'Mission: Impossible',
#  'Jerry Maguire',
#  'Ransom',
#  'Titanic',
#  'Men in Black',
#  'The Lost World: Jurassic Park',
#  'Liar Liar',
#  'Air Force One',
#  'Saving Private Ryan',
#  'Armageddon',
#  "There's Something About Mary",
#  "A Bug's Life",
#  'The Waterboy',
#  'Star Wars: Episode I - The Phantom Menace',
#  'The Sixth Sense',
#  'Toy Story 2',
#  'Austin Powers: The Spy Who Shagged Me',
#  'The Matrix',
#  'How the Grinch Stole Christmas',
#  'Cast Away',
#  'Mission: Impossible II',
#  'Gladiator',
#  'What Women Want',
#  "Harry Potter and the Sorcerer's Stone",
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Shrek',
#  'Monsters, Inc.',
#  'Rush Hour 2',
#  'Spider-Man',
#  'The Lord of the Rings: The Two Towers',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Harry Potter and the Chamber of Secrets',
#  'My Big Fat Greek Wedding',
#  'The Lord of the Rings: The Return of the King',
#  'Finding Nemo',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'The Matrix Reloaded',
#  'Bruce Almighty',
#  'Shrek 2',
#  'Spider-Man 2',
#  'The Passion of the Christ',
#  'Meet the Fockers',
#  'The Incredibles',
#  'Star Wars: Episode III - Revenge of the Sith',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'Harry Potter and the Goblet of Fire',
#  'War of the Worlds',
#  'King Kong',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'Night at the Museum',
#  'Cars',
#  'X-Men: The Last Stand',
#  'The Da Vinci Code',
#  'Spider-Man 3',
#  'Shrek the Third',
#  'Transformers',
#  "Pirates of the Caribbean: At World's End",
#  'Harry Potter and the Order of the Phoenix',
#  'The Dark Knight',
#  'Iron Man',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Hancock',
#  'WALL-E',
#  'Avatar',
#  'Transformers: Revenge of the Fallen',
#  'Harry Potter and the Half-Blood Prince',
#  'The Twilight Saga: New Moon',
#  'Up',
#  'Toy Story 3',
#  'Alice in Wonderland ',
#  'Iron Man 2',
#  'The Twilight Saga: Eclipse',
#  'Harry Potter and the Deathly Hallows Part 1',
#  'Harry Potter and the Deathly Hallows Part 2',
#  'Transformers: Dark of the Moon',
#  'The Twilight Saga: Breaking Dawn Part 1',
#  'The Hangover Part II',
#  'Pirates of the Caribbean: On Stranger Tides',
#  "Marvel's The Avengers",
#  'The Dark Knight Rises',
#  'The Hunger Games',
#  'Skyfall',
#  'The Hobbit: An Unexpected Journey',
#  'The Hunger Games: Catching Fire',
#  'Iron Man 3',
#  'Frozen',
#  'Despicable Me 2',
#  'Man of Steel',
#  'American Sniper',
#  'The Hunger Games: Mockingjay - Part 1',
#  'Guardians of the Galaxy',
#  'Captain America: The Winter Soldier',
#  'The LEGO Movie',
#  'Star Wars: The Force Awakens',
#  'Jurassic World',
#  'Avengers: Age of Ultron',
#  'Inside Out',
#  'Furious 7',
#  'Rogue One: A Star Wars Story',
#  'Finding Dory',
#  'Captain America: Civil War',
#  'The Secret Life of Pets',
#  'The Jungle Book ',
#  'Star Wars: The Last Jedi',
#  'Beauty and the Beast ',
#  'Wonder Woman',
#  'Jumanji: Welcome to the Jungle',
#  'Guardians of the Galaxy Vol. 2']
