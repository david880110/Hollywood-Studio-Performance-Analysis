# %%
# Dependencies
import pandas as pd

# %%
# Read file
yearly_gross = pd.read_csv("dataset/yearly_gross.csv")
studio_gross = pd.read_csv("dataset/studio.csv")

# %%
merge_table = pd.merge(yearly_gross, studio_gross, on="Year")
merge_table.head(15)
# Out:
#     Year  Total_Yearly_Gross Studio  Studio_Gross
# 0   1990          4201762579     BV     683431384
# 1   1990          4201762579    Fox     668375058
# 2   1990          4201762579  Gold.      14560247
# 3   1990          4201762579    MGM      61264584
# 4   1990          4201762579  Mira.      25437170
# 5   1990          4201762579     NL     173193300
# 6   1990          4201762579  Orion     361466795
# 7   1990          4201762579   Par.     648684055
# 8   1990          4201762579   Sony     391166363
# 9   1990          4201762579   TriS     164690048
# 10  1990          4201762579   Triu      55675288
# 11  1990          4201762579     UA      40946358
# 12  1990          4201762579   Uni.     501300428
# 13  1990          4201762579     WB     411571501
# 14  1991          4013340886     BV     639516948

# %%
merge_table["Market_Share"] = df.apply(lambda x:)
merge_table
# Out:
#      Year  Total_Yearly_Gross  Studio  Studio_Gross Market_Share
# 0    1990          4201762579      BV     683431384         None
# 1    1990          4201762579     Fox     668375058         None
# 2    1990          4201762579   Gold.      14560247         None
# 3    1990          4201762579     MGM      61264584         None
# 4    1990          4201762579   Mira.      25437170         None
# 5    1990          4201762579      NL     173193300         None
# 6    1990          4201762579   Orion     361466795         None
# 7    1990          4201762579    Par.     648684055         None
# 8    1990          4201762579    Sony     391166363         None
# 9    1990          4201762579    TriS     164690048         None
# 10   1990          4201762579    Triu      55675288         None
# 11   1990          4201762579      UA      40946358         None
# 12   1990          4201762579    Uni.     501300428         None
# ...
